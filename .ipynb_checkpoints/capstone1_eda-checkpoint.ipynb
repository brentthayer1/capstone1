# %% [markdown]
# # Capstone 1 EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy import spatial
import capstone1_funcs as cs1
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import CSV

# %%
init_df = pd.read_csv('/Volumes/b/Galvanize/DS-RFT4/capstones-RFT4/datasets/music2/SpotifyAudioFeaturesApril2019.csv')

# %%
init_df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
init_df.shape
# Out:
# (130663, 17)

# %% [markdown]
# ## If there are any duplicate songs, they need to be removed

# %%
cs1.drop_duplicates(init_df)
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# 3                                              Lactose      0.029400
# 4                                  Same - Original mix      0.000035
# ...                                                ...           ...
# 130658                                  Come Back Home      0.006780
# 130659                                  Enough for You      0.918000
# 130660                                           Do It      0.330000
# 130661                                        No Smoke      0.007900
# 130662                                         En Vida      0.549000
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0              0.743       238373   0.339             0.000    1    0.0812
# 1              0.846       214800   0.557             0.000    8    0.2860
# 2              0.603       138913   0.723             0.000    9    0.0824
# 3              0.800       125381   0.579             0.912    5    0.0994
# 4              0.783       124016   0.792             0.878    7    0.0332
# ...              ...          ...     ...               ...  ...       ...
# 130658         0.601       190539   0.801             0.000   11    0.0991
# 130659         0.387       194583   0.249             0.000    9    0.1030
# 130660         0.717       139191   0.532             0.000    8    0.0997
# 130661         0.772       180013   0.510             0.000    4    0.1310
# 130662         0.715       145827   0.734             0.000    3    0.1080
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 0         -7.678     1       0.4090  203.927               4   0.1180
# 1         -7.259     1       0.4570  159.009               4   0.3710
# 2         -5.890     0       0.0454  114.966               4   0.3820
# 3        -12.118     0       0.0701  123.003               4   0.6410
# 4        -10.277     1       0.0661  120.047               4   0.9280
# ...          ...   ...          ...      ...             ...      ...
# 130658    -5.174     1       0.0323  131.049               4   0.2890
# 130659   -13.233     1       0.0437   94.039               4   0.3460
# 130660    -8.351     0       0.2060  156.977               4   0.5460
# 130661    -9.670     0       0.1200  120.049               4   0.0755
# 130662    -3.244     1       0.0367  130.128               3   0.9760
#
#         popularity
# 0               15
# 1                0
# 2               56
# 3                0
# 4                0
# ...            ...
# 130658          57
# 130659          60
# 130660          47
# 130661          50
# 130662          55
#
# [130663 rows x 17 columns]

# %% [markdown]
# ## The format of duration_ms is a bit hard to read.  Passing DF through a ms to second converter

# %%
cs1.time_ms_to_sec(init_df)

# %% [markdown]
# ### There is now a new time_seconds column which is easier to interpret

# %%
init_df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  time_seconds  acousticness  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj           238      0.005820
# 1                    BAND DRUM (feat. A$AP Rocky)           214      0.024400
# 2                                   Radio Silence           138      0.025000
# 3                                         Lactose           125      0.029400
# 4                             Same - Original mix           124      0.000035
#
#    danceability  energy  instrumentalness  key  liveness  loudness  mode  \
# 0         0.743   0.339             0.000    1    0.0812    -7.678     1
# 1         0.846   0.557             0.000    8    0.2860    -7.259     1
# 2         0.603   0.723             0.000    9    0.0824    -5.890     0
# 3         0.800   0.579             0.912    5    0.0994   -12.118     0
# 4         0.783   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
init_df.shape
# Out:
# (130663, 17)

# %% [markdown]
# ## Check the data for any NaN values

# %%
cols_list = ['track_id', 'track_name', 'time_seconds', 'acousticness', 'danceability', 
             'energy', 'instrumentalness', 'key', 'liveness', 
             'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 
             'valence', 'popularity']

# %%
cs1.check_for_nans(init_df, cols_list)
# Out:
# NaNs in track_id: 0
# NaNs in track_name: 0
# NaNs in time_seconds: 0
# NaNs in acousticness: 0
# NaNs in danceability: 0
# NaNs in energy: 0
# NaNs in instrumentalness: 0
# NaNs in key: 0
# NaNs in liveness: 0
# NaNs in loudness: 0
# NaNs in mode: 0
# NaNs in speechiness: 0
# NaNs in tempo: 0
# NaNs in time_signature: 0
# NaNs in valence: 0
# NaNs in popularity: 0

# %% [markdown]
# # Drop specific columns

# %% [markdown]
# ### I will drop the speechiness, time_signature, key, and mode columns

# %%
cols_to_drop = ['instrumentalness', 'speechiness', 'time_signature', 'key', 'mode']

# %%
cs1.drop_columns(init_df, cols_to_drop)

# %% [markdown]
# There are a good amount of zeroes in the popularity column.  I decided to remove them.

# %%
mask_above_0 = init_df['popularity'] >= 1

# %%
df = init_df[mask_above_0]

# %%
df
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 41            Mr Little Jeans  3Z78Hd9B1OndIo7XJajwYR
# 42               Orjan Nilsen  16UKw34UY9w40Vc7TOkPpA
# 45                    Burbank  7AgDITo8BVDoh2bXj2psYA
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  time_seconds  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj           238
# 2                                        Radio Silence           138
# 41                                           Forgetter           254
# 42                               Nothing Here But Love           189
# 45                                       Waiting for U           168
# ...                                                ...           ...
# 130658                                  Come Back Home           190
# 130659                                  Enough for You           194
# 130660                                           Do It           139
# 130661                                        No Smoke           180
# 130662                                         En Vida           145
#
#         acousticness  danceability  energy  liveness  loudness    tempo  \
# 0            0.00582         0.743   0.339    0.0812    -7.678  203.927
# 2            0.02500         0.603   0.723    0.0824    -5.890  114.966
# 41           0.12500         0.821   0.512    0.0879    -7.138  128.035
# 42           0.04480         0.574   0.881    0.0756    -2.150  126.131
# 45           0.83200         0.699   0.309    0.1160   -10.790   79.991
# ...              ...           ...     ...       ...       ...      ...
# 130658       0.00678         0.601   0.801    0.0991    -5.174  131.049
# 130659       0.91800         0.387   0.249    0.1030   -13.233   94.039
# 130660       0.33000         0.717   0.532    0.0997    -8.351  156.977
# 130661       0.00790         0.772   0.510    0.1310    -9.670  120.049
# 130662       0.54900         0.715   0.734    0.1080    -3.244  130.128
#
#         valence  popularity
# 0        0.1180          15
# 2        0.3820          56
# 41       0.5430          28
# 42       0.5510          29
# 45       0.4220          31
# ...         ...         ...
# 130658   0.2890          57
# 130659   0.3460          60
# 130660   0.5460          47
# 130661   0.0755          50
# 130662   0.9760          55
#
# [111774 rows x 12 columns]

# %% [markdown]
# ## Gain a general understanding of the data and how it's distributed

# %%
attribute_list = ['time_seconds', 'acousticness', 'danceability', 
                  'energy', 'liveness', 'loudness', 'tempo', 
                  'valence', 'popularity']

color_list = sns.color_palette()

# %%
for att, colr in zip(attribute_list, color_list):
    print(f'Mean value for {att}:', round(df[att].mean(), 2))
    sns.distplot(df[att], color=colr)
    plt.show()
# Out:
# Mean value for time_seconds: 215.08
# Mean value for acousticness: 0.34
# Mean value for danceability: 0.58
# Mean value for energy: 0.57
# Mean value for liveness: 0.19
# Mean value for loudness: -9.83
# Mean value for tempo: 119.47
# Mean value for valence: 0.44
# Mean value for popularity: 28.3

# %% [markdown]
# ## I wanted to examine the relationship between each attribute through the use of a scatter matrix

# %%
# df_scat_matrix = pd.plotting.scatter_matrix(df, figsize=(20, 20))
sns.pairplot(df)

# %% [markdown]
# ## Group together songs by similar popularity rating.  Find the top songs.  Bin together groups of popularity. 8 groups of popularity, all roughly the same sample size. 1 additional group which accounts for the most popular songs

# %% [markdown]
# ### The songs were grouped into 8 groups.

# %% [markdown]
# Out of the 111,774 total songs in the dataframe, I decided that the top 0.1% of these would work as their own dataframe.  The remaining songs were distrubuted between the remaining 10 groups.

# %%
popularity = df.copy().sort_values('popularity', ascending=False)

# %%
popularity.head()
# Out:
#            artist_name                track_id  \
# 99393     Daddy Yankee  5w9c2J52mkdntKOmRLeM2m
# 123909     Post Malone  3KkXRkHbMCARz0aVfEt68P
# 99368    Billie Eilish  2Fxmhks0bxGSBdJ92vM42m
# 99366   Jonas Brothers  4y3OI86AEP6PQoDE6olYhO
# 99364      Post Malone  6MWtB6iiXyIwun0YzU6DFP
#
#                                            track_name  time_seconds  \
# 99393                                       Con Calma           193
# 123909  Sunflower - Spider-Man: Into the Spider-Verse           158
# 99368                                         bad guy           194
# 99366                                          Sucker           181
# 99364                                            Wow.           149
#
#         acousticness  danceability  energy  liveness  loudness    tempo  \
# 99393         0.1100         0.737   0.860    0.0574    -2.652   93.989
# 123909        0.5200         0.744   0.494    0.0716    -5.563   89.972
# 99368         0.3080         0.708   0.418    0.1000   -10.998  131.926
# 99366         0.0427         0.842   0.734    0.1060    -5.065  137.958
# 99364         0.1630         0.833   0.539    0.1010    -7.399   99.947
#
#         valence  popularity
# 99393     0.656         100
# 123909    0.927          98
# 99368     0.578          98
# 99366     0.952          98
# 99364     0.385          98

# %%
df.shape
# Out:
# (111774, 12)

# %% [markdown]
# ## Create masks to separate popularity into new dfs.  Separated as follows:
# - Greater than 86
# - Between 52 and 87
# - Between 41 and 52
# - Between 33 and 41
# - Between 26 and 33
# - Between 20 and 26
# - Between 14 and 20
# - Between 7 and 14
# - Between 1 and 7
#
# Besides the greater than 87 group, each group holds around 13,000 songs now.  This will make it easier to analyze later.

# %% [markdown]
# ### Create masks for each new group

# %%
mask_86 = popularity['popularity'] > 86
mask_52 = (popularity['popularity'] > 52) & (popularity['popularity'] <= 86)
mask_41 = (popularity['popularity'] > 41) & (popularity['popularity'] <= 52)
mask_33 = (popularity['popularity'] > 33) & (popularity['popularity'] <= 41)
mask_26 = (popularity['popularity'] > 26) & (popularity['popularity'] <= 33)
mask_20 = (popularity['popularity'] > 20) & (popularity['popularity'] <= 26)
mask_14 = (popularity['popularity'] > 14) & (popularity['popularity'] <= 20)
mask_7 = (popularity['popularity'] > 7) & (popularity['popularity'] <= 14)
mask_1 = (popularity['popularity'] > 1) & (popularity['popularity'] <= 7)

mask_below_86 = (popularity['popularity'] <= 86) & (popularity['popularity'] > 1)

# %% [markdown]
# ### Apply masks to create new dataframes to work with

# %%
df_86 = popularity[mask_86]
df_52 = popularity[mask_52]
df_41 = popularity[mask_41]
df_33 = popularity[mask_33]
df_26 = popularity[mask_26]
df_20 = popularity[mask_20]
df_14 = popularity[mask_14]
df_7 = popularity[mask_7]
df_1 = popularity[mask_1]

df_below_86 = popularity[mask_below_86]

# %% [markdown]
# ### mask_86 is about 0.12% of the total data

# %%
f'{round(((len(df_86) / len(df)) * 100), 3)} %'
# Out:
# '0.123 %'

# %% [markdown]
# ### New dataframe totals and percents of total data

# %%
df_lst = [df_86, df_52, df_41, df_33, df_26, df_20, df_14, df_7, df_1]
df_name_lst = ['df_86', 'df_52', 'df_41', 'df_33', 'df_26', 'df_20', 'df_14', 'df_7', 'df_1']

for df_, name in zip(df_lst, df_name_lst):
    print(f'{name}: \t Songs:{df_.shape[0]} \n\t Percent:{round((len(df_) / 111774)*100, 2)}%\n')
# Out:
# df_86: 	 Songs:138
# 	 Percent:0.12%
#
# df_52: 	 Songs:13680
# 	 Percent:12.24%
#
# df_41: 	 Songs:13267
# 	 Percent:11.87%
#
# df_33: 	 Songs:12794
# 	 Percent:11.45%
#
# df_26: 	 Songs:14363
# 	 Percent:12.85%
#
# df_20: 	 Songs:13562
# 	 Percent:12.13%
#
# df_14: 	 Songs:14268
# 	 Percent:12.77%
#
# df_7: 	 Songs:14447
# 	 Percent:12.93%
#
# df_1: 	 Songs:12038
# 	 Percent:10.77%

# %% [markdown]
# ## The attribute that drew my attention first was loudness.

# %% [markdown]
# ### I am curious how loudness relates to a track's popularity

# %%
# df_lst = [df_86, df_52, df_41, df_33, df_26, df_20, df_14, df_7, df_1]
# df_name_lst = ['df_86', 'df_52', 'df_41', 'df_33', 'df_26', 'df_20', 'df_14', 'df_7', 'df_1']

# fig, axs = plt.subplots(9, figsize = (8,20))
# def plot_hist(axs, dfs, names, col, color_list):
#     for ax, df_, name, colr in zip(axs, dfs, names, color_list):
#         ax.hist(df_[col], bins=70, color=colr)
#         ax.set_title(name)
#     fig.tight_layout()

# plot_hist(axs, df_lst, df_name_lst, 'loudness', color_list)



attribute = 'loudness'

for df_, colr, name in zip(df_lst, color_list, df_name_lst):
    print(f'Mean value for {attribute} in {name}:', round(df_[attribute].mean(), 2))
    sns.distplot(df_[attribute], color=colr)
    plt.show()
# Out:
# Mean value for loudness in df_86: -6.67
# Mean value for loudness in df_52: -7.49
# Mean value for loudness in df_41: -7.68
# Mean value for loudness in df_33: -8.35
# Mean value for loudness in df_26: -8.95
# Mean value for loudness in df_20: -10.34
# Mean value for loudness in df_14: -10.94
# Mean value for loudness in df_7: -11.37
# Mean value for loudness in df_1: -13.1

# %% [markdown]
# ### Time

# %%
attribute = 'time_seconds'

for df_, colr, name in zip(df_lst, color_list, df_name_lst):
    print(f'Mean value for {attribute} in {name}:', round(df_[attribute].mean(), 2))
    sns.distplot(df_[attribute], color=colr)
    plt.show()
# Out:
# Mean value for time_seconds in df_86: 203.72
# Mean value for time_seconds in df_52: 202.23
# Mean value for time_seconds in df_41: 208.62
# Mean value for time_seconds in df_33: 214.71
# Mean value for time_seconds in df_26: 219.58
# Mean value for time_seconds in df_20: 215.87
# Mean value for time_seconds in df_14: 225.43
# Mean value for time_seconds in df_7: 220.26
# Mean value for time_seconds in df_1: 213.94

# %% [markdown]
# ### Tempo

# %%
attribute = 'tempo'

for df_, colr, name in zip(df_lst, color_list, df_name_lst):
    print(f'Mean value for {attribute} in {name}:', round(df_[attribute].mean(), 2))
    sns.distplot(df_[attribute], color=colr)
    plt.show()
# Out:
# Mean value for tempo in df_86: 117.84
# Mean value for tempo in df_52: 120.81
# Mean value for tempo in df_41: 120.98
# Mean value for tempo in df_33: 121.43
# Mean value for tempo in df_26: 120.31
# Mean value for tempo in df_20: 119.0
# Mean value for tempo in df_14: 118.96
# Mean value for tempo in df_7: 118.58
# Mean value for tempo in df_1: 116.35

# %% [markdown]
# ### Tempo

# %%
attribute = 'loudness'

full_data_mean = np.mean(df[attribute])
full_data_std = np.std(df[attribute])
print(f'df Avg {attribute}: {full_data_mean} STD: {full_data_std}\n')

for df_, name in zip(df_lst, df_name_lst):
    avg_loudness = round(np.mean(df_[attribute]), 3)
    stdev = np.std(df_[attribute])
    length = len(df_[attribute])
    print(f'{name} Avg {attribute}: {avg_loudness} STD: {stdev} Sample Size: {length}')
# Out:
# df Avg loudness: -9.831833655411824 STD: 6.545869949499809
#
# df_86 Avg loudness: -6.667 STD: 3.2180620435457827 Sample Size: 138
# df_52 Avg loudness: -7.492 STD: 4.41932498195089 Sample Size: 13680
# df_41 Avg loudness: -7.679 STD: 4.1458640633368775 Sample Size: 13267
# df_33 Avg loudness: -8.35 STD: 5.079570215145393 Sample Size: 12794
# df_26 Avg loudness: -8.951 STD: 5.5097261395987 Sample Size: 14363
# df_20 Avg loudness: -10.34 STD: 6.9155988048165336 Sample Size: 13562
# df_14 Avg loudness: -10.936 STD: 7.398791609895601 Sample Size: 14268
# df_7 Avg loudness: -11.369 STD: 7.284587611142486 Sample Size: 14447
# df_1 Avg loudness: -13.097 STD: 7.937555619497014 Sample Size: 12038

# %%
fig, ax = plt.subplots(3, figsize=(10, 10))

ax[0].scatter(df_86['popularity'], df_86['loudness'], s=0.5, color='red', alpha=0.5)
ax[0].scatter(df_below_86['popularity'], df_below_86['loudness'], s=0.5, color='blue', alpha=0.5)
ax[0].set_title('Loudness')

ax[1].scatter(df_86['popularity'], df_86['time_seconds'], s=0.5, color='red', alpha=0.5)
ax[1].scatter(df_below_86['popularity'], df_below_86['time_seconds'], s=0.5, color='blue', alpha=0.5)
ax[1].set_title('Time')

ax[2].scatter(df_86['popularity'], df_86['tempo'], s=0.5, color='red', alpha=0.5)
ax[2].scatter(df_below_86['popularity'], df_below_86['time_seconds'], s=0.5, color='blue', alpha=0.5)
ax[2].set_title('Tempo')


;
# Out:
# ''

# %% [markdown]
# ### Mann Whitneyt U test

# %%
mask_upper = popularity['popularity'] > 86
mask_lower = (popularity['popularity'] > 1) & (popularity['popularity'] <= 86)

# %%
df_lower = popularity[mask_lower]
df_upper = popularity[mask_upper]

# %%
df_upper.shape
# Out:
# (138, 12)

# %%
df.shape
# Out:
# (111774, 12)

# %%
df_upper.describe()
# Out:
#        time_seconds  acousticness  danceability      energy    liveness  \
# count    138.000000    138.000000    138.000000  138.000000  138.000000
# mean     203.717391      0.284986      0.727355    0.593231    0.176046
# std       40.827390      0.250866      0.128099    0.172649    0.124467
# min      113.000000      0.003810      0.351000    0.054900    0.055800
# 25%      180.250000      0.065425      0.652000    0.494500    0.100250
# 50%      200.000000      0.199500      0.744500    0.609500    0.122000
# 75%      221.000000      0.413000      0.826000    0.729500    0.238750
# max      417.000000      0.979000      0.950000    0.904000    0.800000
#
#          loudness       tempo     valence  popularity
# count  138.000000  138.000000  138.000000  138.000000
# mean    -6.667420  117.836957    0.467041   90.471014
# std      3.229785   28.320393    0.205653    3.208547
# min    -23.237000   62.442000    0.047300   87.000000
# 25%     -7.691500   96.113250    0.320000   88.000000
# 50%     -5.890500  114.536500    0.466500   89.500000
# 75%     -4.616750  136.041000    0.617250   93.000000
# max     -2.384000  202.006000    0.952000  100.000000

# %%
a, b = df_upper['loudness'], df_lower['loudness']

# %%
stats.mannwhitneyu(a, b)
# Out:
# MannwhitneyuResult(statistic=5086793.5, pvalue=3.821098107040944e-11)

# %%
def bootstrap_sample_means(data, n_bootstrap_samples=10000):
    bootstrap_sample_means = []
    for i in range(n_bootstrap_samples):
        bootstrap_sample = np.random.choice(data, size=len(data), replace=True)
        bootstrap_sample_means.append(np.mean(bootstrap_sample))
    return bootstrap_sample_means
